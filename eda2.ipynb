# %%
import pandas as pd
data=pd.read_csv('cardiotocographic.csv')
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# ## data cleaning and preparation

# %%
data.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
data.tail()
# Out:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.0  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.0  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2121  25.000000   7.2   40.0       0.0  2.000000
# 2122  22.000000   7.1   66.0       1.0  2.000000
# 2123  20.000000   6.1   67.0       1.0  1.990464
# 2124  27.000000   7.0   66.0       1.0  2.000000
# 2125  35.857183   5.0   42.0       0.0  1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
## no datatype conversion needed

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
data.DS.unique()
# Out:
# array([ 0.00000000e+00, -1.79000000e-06,  3.66773608e-06,             nan,
#        -3.24000000e-06,  2.54296927e-06, -2.26000000e-06,  8.65602121e-07,
#         1.16544621e-06,  5.57785247e-07, -2.22000000e-06, -3.09000000e-06,
#        -2.52000000e-06, -3.27000000e-06,  6.32344823e-06, -1.09000000e-06,
#        -5.37000000e-06, -1.70000000e-06,  3.21484620e-06,  3.47927095e-06,
#        -4.21000000e-06,  1.04857389e-06,  2.70636000e-03, -8.96000000e-08,
#         1.39285783e-06, -3.98000000e-07, -4.76000000e-07,  3.55635347e-06,
#         4.07729571e-06,  3.72913403e-06, -2.61000000e-07,  6.18521847e-08,
#        -2.51000000e-06,  1.35429413e-08,  4.56585228e-06, -2.90000000e-06,
#        -2.50000000e-06, -2.05000000e-06, -1.35318000e-03,  4.22410892e-07,
#         3.26310012e-06,  1.94962916e-06, -5.05000000e-06,  3.00612027e-06,
#        -1.22000000e-07,  3.95240056e-07, -3.45000000e-07,  2.25957299e-06,
# ...

# %%
data.DP.unique()
# Out:
# array([ 0.00000000e+00,  2.09863600e-03,  2.80504900e-03,  8.25540000e-04,
#         1.39275800e-03,  1.52439000e-03,  1.42247500e-03,  8.42460000e-04,
#         3.35570500e-03,  1.56250000e-03,  3.04878000e-03,  8.34028000e-04,
#        -1.35000000e-05,             nan,  1.41643100e-03,  4.42571502e-06,
#        -5.34759400e-03,  1.63398700e-03,  2.62470075e-06,  3.00312855e-05,
#         2.29112454e-07,  2.44883220e-06, -5.69000000e-06, -6.21000000e-06,
#         3.29589451e-05, -2.97000000e-05,  1.34541878e-05, -2.74000000e-06,
#        -2.19000000e-05, -2.56000000e-06,  1.24650370e-05,  1.06951880e-02,
#        -1.03000000e-05, -1.63000000e-05,  2.26458634e-06, -1.57000000e-05,
#        -2.25000000e-05,  2.95514208e-06,  8.06513438e-06, -3.43000000e-05,
#        -1.02000000e-06, -9.36000000e-06,  1.25177135e-05,  3.06810554e-06,
#        -2.04000000e-05, -1.88000000e-05,  2.77008300e-03,  2.32018600e-03,
# ...

# %%
data.DL.unique()
# Out:
# array([ 0.00000000e+00,  3.18979300e-03,  3.32225900e-03,  2.56081900e-03,
#         9.44386100e-03,  8.41514700e-03,  8.34028000e-04,  9.83284000e-04,
#         2.53807100e-03,  1.51285900e-03,  5.00417000e-03,  4.17827300e-03,
#         4.56621000e-03,  4.57317100e-03,  4.26742500e-03,  4.21230000e-03,
#         2.23713600e-03,  3.12500000e-03,  3.04878000e-03,  9.06905521e-05,
#        -3.50000000e-05,  8.34028400e-03,  1.21580550e-02,  1.00083400e-02,
#         1.41643060e-02,  9.63698000e-03,  1.51745100e-03,  2.50208500e-03,
#         3.03951400e-03,  1.24843900e-03,  5.14138800e-03,  5.75539600e-03,
#         2.23214300e-03,  6.00600600e-03,  7.53012000e-03,  8.49858400e-03,
#        -5.90000000e-05,  1.66805700e-03,  9.03342000e-04,  2.27790400e-03,
#         3.02571900e-03,  1.31233600e-03,  8.30565000e-04,  3.22580600e-03,
#         4.17014200e-03,  8.29875500e-03,  1.82920600e-03,  4.83091800e-03,
# ...

# %%
data[data.duplicated()]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
data=data.drop_duplicates()

# %%
data.reset_index(inplace=True)
data
# Out:
#       index          LB        AC        FM        UC        DL   DS   DP  \
# 0         0  120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0
# 1         1  132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0
# 2         2  133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0
# 3         3  134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0
# 4         4  131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0
# ...     ...         ...       ...       ...       ...       ...  ...  ...
# 2119   2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0
# 2120   2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0
# 2121   2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0
# 2122   2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0
# 2123   2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0
#
#       ASTV  MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
data.drop(['index'],axis=1,inplace=True)
# Out:
# C:\Users\user2\AppData\Local\Temp\ipykernel_7604\1833406359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['index'],axis=1,inplace=True)

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2119  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2120  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2121  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2123  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
data.isnull()
# Out:
#          LB     AC     FM     UC     DL     DS     DP   ASTV   MSTV   ALTV  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2119  False  False  False  False  False  False  False  False  False  False
# 2120  False  False  False  False  False  False  False  False  False  False
# 2121  False  False  False  False  False  False  False  False  False  False
# 2122  False  False  False  False  False  False  False  False  False  False
# 2123  False  False  False  False  False  False  False  False  False  False
#
#        MLTV  Width  Tendency    NSP
# ...

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 167

# %%
data[data.isnull().any(axis=1)]
# Out:
#       LB        AC        FM        UC        DL  DS  DP       ASTV      MSTV  \
# 50   NaN       NaN  0.000000  0.008086  0.000000 NaN NaN  29.000000  1.300000
# 116  NaN  0.038567  0.000000  0.006993  0.002331 NaN NaN  26.000000  4.300000
# 126  NaN       NaN  0.000000  0.004380  0.000000 NaN NaN  69.000000  0.300000
# 201  NaN       NaN  0.016393  0.000000  0.000000 NaN NaN  56.000000  0.500000
# 566  NaN       NaN  0.000000  0.004115  0.005487 NaN NaN  43.000000  2.500000
# 574  NaN       NaN  0.000000  0.002611  0.002611 NaN NaN  34.000000  4.900000
# 603  NaN       NaN  0.006519  0.001304  0.001304 NaN NaN  73.000000  0.700000
# 935  NaN       NaN  0.000000  0.005495  0.001374 NaN NaN  30.000000  1.251793
# 936  NaN       NaN  0.000000  0.007802  0.000000 NaN NaN  33.000000  1.000000
# 1013 NaN       NaN  0.000000  0.003861  0.000000 NaN NaN  34.000000  1.000000
# 1204 NaN       NaN -0.000129  0.006424  0.000000 NaN NaN  63.000000  0.500000
# ...

# %%
data=data.dropna()

# %%
data.reset_index(inplace=True)

# %%
data.drop(['index'],axis=1,inplace=True)
# Out:
# C:\Users\user2\AppData\Local\Temp\ipykernel_7604\1833406359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['index'],axis=1,inplace=True)

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2098  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2099  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2100  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2101  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2102  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
data.shape
# Out:
# (2103, 14)

# %%
data.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
data.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2103.000000  2103.000000  2103.000000  2103.000000  2103.000000
# mean    133.342023     0.003203     0.009973     0.004391     0.001894
# std      11.268266     0.004325     0.067902     0.003350     0.003349
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001838     0.000000
# 50%     133.000000     0.001631     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002559     0.006543     0.003295
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2103.000000  2103.000000  2103.000000  2103.000000  2103.000000
# mean      0.000003     0.000175    47.013569     1.360968    10.363493
# std       0.000142     0.000840    18.846186     1.173620    21.289827
# ...

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
for col in data.select_dtypes(include=[np.number]).columns:
    plt.figure(figsize=(6, 1.5))
    sns.boxplot(x=data[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
data1=data.copy(deep=True)

# %%
for col in data1.columns:
    q1=data1[col].quantile(0.25)
    q3=data1[col].quantile(0.75)
    iqr=q3-q1
    le=q1-1.5*iqr
    ue=q3+1.5*iqr
    median=data1[col].median()

    data1[col]=np.where((data1[col]<le)|(data1[col]>ue),median,data[col])

# %% [markdown]
# ## statistical Summary

# %%
import numpy as np
import pandas as pd

summary=pd.DataFrame()

summary['Mean']=data.mean()
summary['Median']=data.median()
summary['Std Deviation']=data.std()
summary['IQR']=data.quantile(0.75)-data.quantile(0.25)

print(summary)
# Out:
#                 Mean      Median  Std Deviation        IQR
# LB        133.342023  133.000000      11.268266  14.000000
# AC          0.003203    0.001631       0.004325   0.005650
# FM          0.009973    0.000000       0.067902   0.002559
# UC          0.004391    0.004484       0.003350   0.004705
# DL          0.001894    0.000000       0.003349   0.003295
# DS          0.000003    0.000000       0.000142   0.000000
# DP          0.000175    0.000000       0.000840   0.000000
# ASTV       47.013569   49.000000      18.846186  29.000000
# MSTV        1.360968    1.200000       1.173620   1.000000
# ALTV       10.363493    0.000000      21.289827  11.000000
# MLTV        8.280546    7.400000       7.774969   6.300000
# Width      70.461052   67.486468      42.939806  63.000000
# Tendency    0.316672    0.000000       0.645855   1.000000
# NSP         1.304797    1.000000       0.644857   0.000000

# %% [markdown]
# ## data visulaization

# %%
data1.drop(['DP','DS','NSP'],axis=1,inplace=True)

# %%
data1.hist(figsize=(15, 12), bins=30, edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'LB'}>, <Axes: title={'center': 'AC'}>,
#         <Axes: title={'center': 'FM'}>],
#        [<Axes: title={'center': 'UC'}>, <Axes: title={'center': 'DL'}>,
#         <Axes: title={'center': 'ASTV'}>],
#        [<Axes: title={'center': 'MSTV'}>,
#         <Axes: title={'center': 'ALTV'}>,
#         <Axes: title={'center': 'MLTV'}>],
#        [<Axes: title={'center': 'Width'}>,
#         <Axes: title={'center': 'Tendency'}>, <Axes: >]], dtype=object)

# %%
data1.boxplot(figsize=(15, 12))
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12, 10))
corr = data1.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
import seaborn as sns
sns.pairplot(data1)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(12, 10))
sns.violinplot(data1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## PATTERN INSIGHTS

# %%
data1.corr(method="pearson")
# Out:
#                 LB        AC        FM        UC        DL      ASTV  \
# LB        1.000000 -0.095024  0.013616 -0.153453 -0.104256  0.305323
# AC       -0.095024  1.000000 -0.003713  0.123217 -0.005092 -0.266509
# FM        0.013616 -0.003713  1.000000 -0.163371  0.015681  0.287690
# UC       -0.153453  0.123217 -0.163371  1.000000  0.243864 -0.231598
# DL       -0.104256 -0.005092  0.015681  0.243864  1.000000 -0.159103
# ASTV      0.305323 -0.266509  0.287690 -0.231598 -0.159103  1.000000
# MSTV     -0.329148  0.223283  0.006428  0.312461  0.439440 -0.437933
# ALTV      0.156944 -0.225125 -0.038616 -0.072257 -0.110154  0.134367
# MLTV     -0.076652 -0.133579 -0.084544 -0.087893 -0.135023 -0.302113
# Width    -0.142768  0.278523  0.025305  0.138669  0.455418 -0.258062
# Tendency  0.294227  0.007915  0.008848 -0.077930  0.115662 -0.006925
#
#               MSTV      ALTV      MLTV     Width  Tendency
# LB       -0.329148  0.156944 -0.076652 -0.142768  0.294227
# ...

# %%
# Strong positive correlation: close to +1

# Strong negative correlation: close to –1

# No correlation: around 0

# %%
# heatmap of correlation above
